# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host = "localhost", user = "root", passwd = "431170")

# %%
mydb

# %%
cursor = mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('information_schema',),
#  ('mysql',),
#  ('nesibe',),
#  ('nesibe1',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('test',),
#  ('world',)]

# %%
cursor.execute("create database nesibe1")

# %%
cursor.execute ("create table nesibe.cars (x1 varchar(20), x2 varchar(20), x3 varchar(20), x4 varchar(20), x5 varchar(20), x6 varchar(20), x7 varchar(20))")

# %%
db = conn.connect(host = "localhost", user = "root", database = "nesibe", passwd  = "431170" )

# %%
cursor = db.cursor()

# %%
cursor.execute("show tables")
cursor.fetchall()
# Out:
# [('cars',)]

# %%
import csv
with open("car.txt", "r") as f:
    data = csv.reader(f, delimiter = "\n")
    for i in data:
        print(i[0])
# Out:
# vhigh,vhigh,2,2,small,low,unacc
# vhigh,vhigh,2,2,small,med,unacc
# vhigh,vhigh,2,2,small,high,unacc
# vhigh,vhigh,2,2,med,low,unacc
# vhigh,vhigh,2,2,med,med,unacc
# vhigh,vhigh,2,2,med,high,unacc
# vhigh,vhigh,2,2,big,low,unacc
# vhigh,vhigh,2,2,big,med,unacc
# vhigh,vhigh,2,2,big,high,unacc
# vhigh,vhigh,2,4,small,low,unacc
# vhigh,vhigh,2,4,small,med,unacc
# vhigh,vhigh,2,4,small,high,unacc
# vhigh,vhigh,2,4,med,low,unacc
# vhigh,vhigh,2,4,med,med,unacc
# vhigh,vhigh,2,4,med,high,unacc
# vhigh,vhigh,2,4,big,low,unacc
# vhigh,vhigh,2,4,big,med,unacc
# vhigh,vhigh,2,4,big,high,unacc
# vhigh,vhigh,2,more,small,low,unacc
# vhigh,vhigh,2,more,small,med,unacc
# vhigh,vhigh,2,more,small,high,unacc
# vhigh,vhigh,2,more,med,low,unacc
# vhigh,vhigh,2,more,med,med,unacc
# vhigh,vhigh,2,more,med,high,unacc
# vhigh,vhigh,2,more,big,low,unacc
# vhigh,vhigh,2,more,big,med,unacc
# vhigh,vhigh,2,more,big,high,unacc
# vhigh,vhigh,3,2,small,low,unacc
# vhigh,vhigh,3,2,small,med,unacc
# ...

# %%
insert_stmt = (
   "INSERT INTO nesibe.cars(x1, x2, x3, x4, x5, x6, x7)"
   "VALUES (%s, %s, %s, %s, %s, %s, %s)"
)

with open ("car.data", "r") as f:
    data = f.readlines()
values = [data[0].split(',') for line in data]

cursor.executemany(insert_stmt, values)

# %%
db.commit
# Out:
# <bound method CMySQLConnection.commit of <mysql.connector.connection_cext.CMySQLConnection object at 0x000001F7D1111250>>

# %%
cursor.execute("select * from cars")

# %%
cursor.fetchall()
# Out:
# [('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
#  ('vhigh', 'vhigh', '2', '2', 'small', 'low', 'unacc\n'),
# ...

# %%
cursor.execute("select x1, count(*) from cars group by x1")
cursor.fetchall()
# Out:
# [('vhigh', 1728)]

# %%
cursor.execute("select * from cars where x3 = 4")
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("update cars set x3 = 8 where x3 = 2")
db.commit
# Out:
# <bound method CMySQLConnection.commit of <mysql.connector.connection_cext.CMySQLConnection object at 0x000001F7D1111250>>

# %%
cursor.execute("select * from cars where x3 = 2")
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("drop table cars ")

# %%
cursor.execute("drop database nesibe1")
