# %%
import pandas as pd

# %% [markdown]
# # task1 data

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
q1. find out how many male and female was on boarded
q2. how many survived we have
q3. how many casuality we have
q4. what is the name of a  person who is eldest one
q5. how many passengers do we have, in first, second, and third class
q6. how many person we have whose name starts with "s"
q7. try to create a new column whih is summation of "SibSp" and "Parch"
q8. how many person do we have below age of 25
q9. how many person died whose age  was less then 40
q10. from a cabin column seperate text and numeric value

# %%
#q1 find out how many male and female was on boarded
print("male is = " , sum(df["Sex"]=="male"), "female number is ", sum(df["Sex"]=="female"))
# Out:
# male is =  577 female number is  314

# %%
#q2 how many survived we have

len(df [df["Survived"] ==1].index)

##or 

df[df["Survived"] ==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#q3 how many casuality we have
col_ind = df[df["Survived"]==0].index

# %%
#q3 cont.
df.loc[col_ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
##q4. what is the name of a  person who is eldest one
max(df["Age"])
df["Age"]== max(df["Age"])
# Out:
# 80.0

# %%
##q4 cont.
df[df["Age"] == max(df["Age"])]["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
##q5. how many passengers do we have, in first, second, and third class
df.groupby("Pclass").size() ##group by and counting each class
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# dtype: int64

# %%
##q6 how many person we have whose name starts with "s"
len(df [df["Name"].str.startswith("s") | df["Name"].str.startswith("S")])
# Out:
# 86

# %%
##q7. try to create a new column whih is summation of "SibSp" and "Parch"
df["SibSpParch"] = df["SibSp"] + df["Parch"]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
##q8. how many person do we have below age of 25
len(df[df["Age"]> 25].index) ##answer is just that
ind = df[df["Age"]>25].index 
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 883          884         0       2
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
##q9. how many person died whose age  was less then 40
ind = df[df["Age"]<40].index

# %%
df_new = df.loc[ind].reset_index()

# %%
df_new [df_new["Survived"]==0].reset_index()
# Out:
#      level_0  index  PassengerId  Survived  Pclass  \
# 0          0      0            1         0       3
# 1          4      4            5         0       3
# 2          5      7            8         0       3
# 3          9     12           13         0       3
# 4         10     13           14         0       3
# ..       ...    ...          ...       ...     ...
# 317      544    883          884         0       2
# 318      545    884          885         0       3
# 319      546    885          886         0       3
# 320      547    886          887         0       2
# 321      550    890          891         0       3
#
#                                      Name     Sex   Age  SibSp  Parch  \
# 0                 Braund, Mr. Owen Harris    male  22.0      1      0
# 1                Allen, Mr. William Henry    male  35.0      0      0
# 2          Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...

# %%
# for q9 why this method is not working
df[df["Age"]<40].reset_index() & df[df["Survived"]==0].reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17776/3495564155.py in <module>
# ----> 1 df[df["Age"]<40].reset_index() and df[df["Survived"]==0].reset_index()
#
# D:\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
## q10. from a cabin column seperate text and numeric value
for i,j in df["Cabin"].items():
    print(j)
# Out:
# nan
# C85
# nan
# C123
# nan
# nan
# E46
# nan
# nan
# nan
# G6
# C103
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# D56
# nan
# A6
# nan
# nan
# nan
# C23 C25 C27
# nan
# nan
# nan
# B78
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# D33
# nan
# B30
# C52
# nan
# nan
# nan
# nan
# nan
# B28
# C83
# nan
# nan
# nan
# F33
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# F G73
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C23 C25 C27
# nan
# nan
# nan
# E31
# nan
# nan
# nan
# A5
# D10 D12
# nan
# nan
# nan
# nan
# D26
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# C110
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# B58 B60
# nan
# nan
# nan
# nan
# E101
# D26
# nan
# nan
# nan
# F E69
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# D47
# C123
# nan
# B86
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# F2
# nan
# nan
# C2
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ...

# %%
df[['Cabin_text','Cabin_number']]=df["Cabin"].str.extract('([a-zA-Z]+)([^a-zA-Z]+)', expand=True)

# %%
df.tail(60)
# Out:
#      PassengerId  Survived  Pclass  \
# 831          832         1       2
# 832          833         0       3
# 833          834         0       3
# 834          835         0       3
# 835          836         1       1
# 836          837         0       3
# 837          838         0       3
# 838          839         1       3
# 839          840         1       1
# 840          841         0       3
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# ...

# %% [markdown]
# # task2

# %%
pd.read_csv(r"C:\Users\User\Downloads\bank\bank.csv", sep = ";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
q1. how many campaign available in this dataset
q2. how many users do we have with housing and personal loan
q3. how many person do we have whose age is 60+
q4. in which month we have targeted most of the customers
q5. which mode of call is giving you more result
q6. how many entrepreneurs do we have in this list
q7. how many customers do we have with negative balance
q8. prepare of group of data based on educational level

# %%
df = pd.read_csv(r"C:\Users\User\Downloads\bank\bank.csv", sep = ";")

# %%
#q1. how many campaign available in this dataset
df["campaign"].sum()
# Out:
# 12630

# %%
##q2. how many users do we have with housing and personal loan

new_df = df[df["housing"]=="yes"]

# %%
new_df[new_df["loan"] =="yes"]
# Out:
#       age            job  marital  education default  balance housing loan  \
# 1      33       services  married  secondary      no     4789     yes  yes
# 3      30     management  married   tertiary      no     1476     yes  yes
# 9      43       services  married    primary      no      -88     yes  yes
# 14     31    blue-collar  married  secondary      no      360     yes  yes
# 48     32   entrepreneur   single    primary     yes     -849     yes  yes
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4502   42       services  married  secondary      no      -91     yes  yes
# 4504   42    blue-collar   single  secondary      no     1080     yes  yes
# 4508   42         admin.  married    unknown      no      642     yes  yes
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
##q3. how many person do we have whose age is 60+
df[df["age"]>60].reset_index()
# Out:
#      index  age         job   marital  education default  balance housing  \
# 0       27   67     retired   married    unknown      no      696      no
# 1       30   68     retired  divorced  secondary      no     4189      no
# 2       36   78     retired  divorced    primary      no      229      no
# 3       49   61      admin.   married    unknown      no     4629     yes
# 4       61   63     retired   married  secondary      no      415     yes
# ..     ...  ...         ...       ...        ...     ...      ...     ...
# 122   4337   73     retired   married    unknown      no      519      no
# 123   4364   63     retired  divorced  secondary      no     1490      no
# 124   4388   83     retired  divorced    primary      no     1097      no
# 125   4413   65     retired   married    primary      no      493      no
# 126   4466   61  management   married  secondary      no      967      no
#
#     loan    contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
##q4. in which month we have targeted most of the customers
df["count"] =1

# %%
df_max = df[df["y"]=="yes"].groupby("month").sum()

# %%
df_max[df_max["count"]==max(df_max["count"])][["count"]]
# Out:
#        count
# month
# may       93

# %%
##q5. which mode of call is giving you more result
df_call = df[df["y"] =="yes"]

# %%
df_call.groupby("contact").size()
# Out:
# contact
# cellular     416
# telephone     44
# unknown       61
# dtype: int64

# %%
##q6. how many entrepreneurs do we have in this list
len(df[df["job"]=="entrepreneur"])
# Out:
# 168

# %%
###q7. how many customers do we have with negative balance
len(df[df["balance"]<0])
# Out:
# 366

# %%
##q8. prepare of group of data based on educational level
for i in df.sort_values("education").groupby("education"):
    print(i)
# Out:
# ('primary',       age          job  marital education default  balance housing loan  \
# 0      30   unemployed  married   primary      no     1787      no   no
# 1984   56  blue-collar  married   primary      no      551      no   no
# 992    39  blue-collar  married   primary      no      879     yes   no
# 994    59    housemaid  married   primary      no        0      no   no
# 3255   55  blue-collar  married   primary      no      284      no  yes
# ...   ...          ...      ...       ...     ...      ...     ...  ...
# 384    41  blue-collar  married   primary      no        8     yes   no
# 385    45  blue-collar  married   primary      no       61      no   no
# 347    55   management  married   primary      no     2587      no   no
# 4176   32  blue-collar  married   primary      no      415     yes   no
# 218    49  blue-collar  married   primary      no      305     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y  \
# ...

# %%
df.sort_values("education").groupby("education").size()
# Out:
# education
# primary       678
# secondary    2306
# tertiary     1350
# unknown       187
# dtype: int64
